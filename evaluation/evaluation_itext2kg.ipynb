# %%
from langchain_openai import ChatOpenAI, OpenAIEmbeddings

openai_api_key = "###"

openai_llm_model = ChatOpenAI(
    api_key = openai_api_key,
    model="gpt-4o",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
)

openai_embeddings_model = OpenAIEmbeddings(
    api_key = openai_api_key ,
    model="text-embedding-3-large",
)

# %% [markdown]
# # Loading the datasets

# %%
import pandas as pd
import ast

def recover_list_dfs(df):
    for col in df.columns:
        if df[col].dtype == object:  # Ensure we only process object (string) columns
            first_valid_index = df[col].first_valid_index()
            if first_valid_index is not None and isinstance(df[col].loc[first_valid_index], str):
                first_value = df[col].loc[first_valid_index].strip()  # Strip any whitespace
                if first_value.startswith("[") and first_value.endswith("]"):  # Ensure it's a list format
                    def safe_eval(x):
                        try:
                            return ast.literal_eval(x) if isinstance(x, str) else x
                        except (SyntaxError, ValueError) as e:
                            print(f"Skipping invalid value in column '{col}': {x} -> {e}")
                            return None  # Return None for problematic values
                    df[col] = df[col].apply(safe_eval)
                    
    return df
    

df_news = recover_list_dfs(pd.read_excel("../datasets/news/df_news_all_llms_eval.xlsx"))
df_abstracts = recover_list_dfs(pd.read_excel("../datasets/abstracts/df_abstracts_all_llms_eval.xlsx"))

# %%
import ast
from itertools import chain

factoids = list(chain(*[ast.literal_eval(fact) for fact in df_news["factoids_ground_truth"]]))

# %%
from itext2kg import iText2KG
# Out:
# /Users/yassirlairgi/.pyenv/versions/3.11.1/envs/test-itext2kg/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:502: UserWarning: <built-in function array> is not a Python type (it may be an instance of an object), Pydantic will allow any object with no validation since we cannot even enforce that the input is an instance of the given type. To get rid of this error wrap the type with `pydantic.SkipValidation`.
#   warn(

# %%
itext2kg= iText2KG(llm_model=openai_llm_model, embeddings_model=openai_embeddings_model)

# %%
from datetime import datetime
import time
import pandas as pd

def calculate_latency(factoids: list[str]):
    results = []
    for i in range(1, len(factoids), 20):
        try:
            start = time.perf_counter()
            itext2kg.build_graph(sections=factoids[:i])
            end = time.perf_counter()
            elapsed_time = end - start
            results.append({"number of factoids": i, "itext2kg's execution time": elapsed_time})
        except Exception as e:
            # Retry once after error
            print(f"Error processing {i} factoids on first attempt: {e}. Retrying...")
            try:
                start = time.perf_counter()
                itext2kg.build_graph(sections=factoids[:i])
                end = time.perf_counter()
                elapsed_time = end - start
                results.append({"number of factoids": i, "itext2kg's execution time": elapsed_time})
            except Exception as e_retry:
                # If retry fails, log the error and continue
                print(f"Error processing {i} factoids on retry: {e_retry}. Skipping...")
                results.append({"number of factoids": i, "itext2kg's execution time": None, "error": str(e_retry)})
        finally:
            # Save progress after each iteration
            pd.DataFrame(results).to_excel("scalability_itext2kg.xlsx", index=False)
    return pd.DataFrame(results)

# %%
calculate_latency(factoids=factoids)
# Out:
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Copenhagen', 'label': 'Location'}, {'name': 'International Climate Summit', 'label': 'Event'}, {'name': 'World Leaders', 'label': 'Group'}, {'name': 'November 2, 2025', 'label': 'Date'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'world leaders', 'label': 'Group'}, 'endNode': {'name': 'international climate summit', 'label': 'Event'}, 'name': 'attended'}, {'startNode': {'name': 'international climate summit', 'label': 'Event'}, 'endNode': {'name': 'copenhagen', 'label': 'Location'}, 'name': 'held in'}, {'startNode': {'name': 'international climate summit', 'label': 'Event'}, 'endNode': {'name': 'november 2, 2025', 'label': 'Date'}, 'name': 'occurred on'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Copenhagen', 'label': 'Location'}, {'name': 'International Climate Summit', 'label': 'Event'}, {'name': 'World Leaders', 'label': 'Group'}, {'name': 'November 2, 2025', 'label': 'Date'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'world leaders', 'label': 'Group'}, 'endNode': {'name': 'international climate summit', 'label': 'Event'}, 'name': 'attended'}, {'startNode': {'name': 'international climate summit', 'label': 'Event'}, 'endNode': {'name': 'copenhagen', 'label': 'Location'}, 'name': 'held in'}, {'startNode': {'name': 'international climate summit', 'label': 'Event'}, 'endNode': {'name': 'november 2, 2025', 'label': 'Date'}, 'name': 'occurred on'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 2
# {'entities': [{'name': 'Summit', 'label': 'Event'}, {'name': 'Carbon Emissions', 'label': 'Environmental Issue'}, {'name': 'Reducing', 'label': 'Action'}]}
# [INFO] Wohoo! Entity was matched --- [summit:Event] --merged--> [international climate summit:Event]
# [INFO] ------- Extracting Relations from the Document 2
# {'relationships': [{'startNode': {'name': 'international climate summit', 'label': 'Event'}, 'endNode': {'name': 'carbon emissions', 'label': 'Environmental_Issue'}, 'name': 'aimed at reducing'}]}
# [INFO] Verification of invented entities
# [INFO][ISOLATED ENTITIES][TRY-1] Aie; there are some isolated entities without relations [Entity(name=reducing, label=Action, properties=embeddings=array([ 0.00688144,  0.01155808, -0.00014781, ..., -0.00843704,
#        -0.00868444, -0.00195104]))]. Solving them ...
# {'relationships': []}
# [INFO] Verification of invented entities
# [INFO][ISOLATED ENTITIES][TRY-2] Aie; there are some isolated entities without relations [Entity(name=carbon emissions, label=Environmental_Issue, properties=embeddings=array([-0.01757862, -0.00755401, -0.00286649, ..., -0.00333453,
#         0.01406073,  0.01860247])), Entity(name=international climate summit, label=Event, properties=embeddings=array([-0.01037433, -0.00979767, -0.01399343, ...,  0.00713611,
#         0.0114244 ,  0.00961558])), Entity(name=reducing, label=Action, properties=embeddings=array([ 0.00688144,  0.01155808, -0.00014781, ..., -0.00843704,
#        -0.00868444, -0.00195104]))]. Solving them ...
# {'relationships': [{'startNode': {'name': 'international climate summit', 'label': 'Event'}, 'endNode': {'name': 'carbon emissions', 'label': 'Environmental_Issue'}, 'name': 'aims to address'}, {'startNode': {'name': 'reducing', 'label': 'Action'}, 'endNode': {'name': 'carbon emissions', 'label': 'Environmental_Issue'}, 'name': 'targets'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 3
# {'entities': [{'name': 'Renewable Energy Targets', 'label': 'Topic'}, {'name': 'Summit', 'label': 'Event'}, {'name': 'Debates', 'label': 'Activity'}]}
# [INFO] Wohoo! Entity was matched --- [summit:Event] --merged--> [international climate summit:Event]
# [INFO] ------- Extracting Relations from the Document 3
# {'relationships': [{'startNode': {'name': 'international climate summit', 'label': 'Event'}, 'endNode': {'name': 'debates', 'label': 'Activity'}, 'name': 'features'}, {'startNode': {'name': 'debates', 'label': 'Activity'}, 'endNode': {'name': 'renewable energy targets', 'label': 'Topic'}, 'name': 'on'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 4
# {'entities': [{'name': 'Summit', 'label': 'Event'}, {'name': 'Debates', 'label': 'Process'}, {'name': 'Financing Mechanisms', 'label': 'Technique'}, {'name': 'Green Projects', 'label': 'Project'}]}
# [INFO] Wohoo! Entity was matched --- [summit:Event] --merged--> [international climate summit:Event]
# [INFO] Wohoo! Entity was matched --- [debates:Process] --merged--> [debates:Activity]
# [INFO] ------- Extracting Relations from the Document 4
# {'relationships': [{'startNode': {'name': 'debates', 'label': 'Activity'}, 'endNode': {'name': 'financing mechanisms', 'label': 'Technique'}, 'name': 'feature'}, {'startNode': {'name': 'financing mechanisms', 'label': 'Technique'}, 'endNode': {'name': 'green projects', 'label': 'Project'}, 'name': 'support'}]}
# [INFO] Verification of invented entities
# [INFO][ISOLATED ENTITIES][TRY-1] Aie; there are some isolated entities without relations [Entity(name=international climate summit, label=Event, properties=embeddings=array([-0.01037433, -0.00979767, -0.01399343, ...,  0.00713611,
#         0.0114244 ,  0.00961558]))]. Solving them ...
# {'relationships': []}
# [INFO] Verification of invented entities
# [INFO][ISOLATED ENTITIES][TRY-2] Aie; there are some isolated entities without relations [Entity(name=green projects, label=Project, properties=embeddings=array([-0.02619267,  0.01773094, -0.02058948, ..., -0.00423038,
#         0.00286425,  0.00577901])), Entity(name=financing mechanisms, label=Technique, properties=embeddings=array([-0.00929729,  0.01575436, -0.01968052, ..., -0.00652727,
#        -0.00100742, -0.00809987])), Entity(name=international climate summit, label=Event, properties=embeddings=array([-0.01037433, -0.00979767, -0.01399343, ...,  0.00713611,
#         0.0114244 ,  0.00961558])), Entity(name=debates, label=Activity, properties=embeddings=array([ 0.00349117,  0.02082128, -0.01317677, ..., -0.01045116,
#         0.00780615, -0.00751667]))]. Solving them ...
# {'relationships': [{'startNode': {'name': 'debates', 'label': 'Activity'}, 'endNode': {'name': 'financing mechanisms', 'label': 'Technique'}, 'name': 'involves'}, {'startNode': {'name': 'debates', 'label': 'Activity'}, 'endNode': {'name': 'green projects', 'label': 'Project'}, 'name': 'focuses on'}, {'startNode': {'name': 'international climate summit', 'label': 'Event'}, 'endNode': {'name': 'debates', 'label': 'Activity'}, 'name': 'features'}]}
# [INFO] Verification of invented entities
# [INFO] Wohoo! Relation was matched --- [features] --merged --> [feature]
# [INFO] Wohoo! Relation was matched --- [feature] --merged --> [features]
# [INFO] Wohoo! Relation was matched --- [feature] --merged --> [features]
# [INFO] ------- Extracting Entities from the Document 5
# {'entities': [{'name': 'Delegates', 'label': 'Group'}, {'name': 'Countries', 'label': 'Geopolitical Entity'}, {'name': 'Coordinated Action', 'label': 'Process'}]}
# [INFO] ------- Extracting Relations from the Document 5
# {'relationships': [{'startNode': {'name': 'delegates', 'label': 'Group'}, 'endNode': {'name': 'countries', 'label': 'Geopolitical_Entity'}, 'name': 'represent'}, {'startNode': {'name': 'delegates', 'label': 'Group'}, 'endNode': {'name': 'coordinated action', 'label': 'Process'}, 'name': 'emphasize'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 6
# {'entities': [{'name': 'Environmental groups', 'label': 'Organization'}, {'name': 'commitments', 'label': 'Concept'}, {'name': 'summit', 'label': 'Event'}]}
# [INFO] Wohoo! Entity was matched --- [summit:Event] --merged--> [international climate summit:Event]
# [INFO] ------- Extracting Relations from the Document 6
# {'relationships': [{'startNode': {'name': 'environmental groups', 'label': 'Organization'}, 'endNode': {'name': 'commitments', 'label': 'Concept'}, 'name': 'lauded'}, {'startNode': {'name': 'commitments', 'label': 'Concept'}, 'endNode': {'name': 'international climate summit', 'label': 'Event'}, 'name': 'made at'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 7
# {'entities': [{'name': 'Negotiators', 'label': 'Person'}, {'name': 'Consensus', 'label': 'Process'}, {'name': 'Interim Emission Reduction Goals', 'label': 'Objective'}]}
# [INFO] ------- Extracting Relations from the Document 7
# {'relationships': [{'startNode': {'name': 'negotiators', 'label': 'Person'}, 'endNode': {'name': 'consensus', 'label': 'Process'}, 'name': 'reached'}, {'startNode': {'name': 'consensus', 'label': 'Process'}, 'endNode': {'name': 'interim emission reduction goals', 'label': 'Objective'}, 'name': 'on'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 8
# {'entities': [{'name': 'Ohio', 'label': 'Location'}, {'name': 'local election', 'label': 'Event'}, {'name': 'October 15, 2025', 'label': 'Date'}, {'name': 'voters', 'label': 'Group'}]}
# [INFO] Wohoo! Entity was matched --- [october 15, 2025:Date] --merged--> [november 2, 2025:Date]
# [INFO] ------- Extracting Relations from the Document 8
# {'relationships': [{'startNode': {'name': 'voters', 'label': 'Group'}, 'endNode': {'name': 'local election', 'label': 'Event'}, 'name': 'participated in'}, {'startNode': {'name': 'local election', 'label': 'Event'}, 'endNode': {'name': 'ohio', 'label': 'Location'}, 'name': 'held in'}]}
# [INFO] Verification of invented entities
# [INFO][ISOLATED ENTITIES][TRY-1] Aie; there are some isolated entities without relations [Entity(name=november 2, 2025, label=Date, properties=embeddings=array([-0.01087675, -0.00051011, -0.00677787, ..., -0.00349423,
#        -0.00276165, -0.00237552]))]. Solving them ...
# {'relationships': []}
# [INFO] Verification of invented entities
# [INFO][ISOLATED ENTITIES][TRY-2] Aie; there are some isolated entities without relations [Entity(name=november 2, 2025, label=Date, properties=embeddings=array([-0.01087675, -0.00051011, -0.00677787, ..., -0.00349423,
#        -0.00276165, -0.00237552])), Entity(name=local election, label=Event, properties=embeddings=array([-0.00306119, -0.01255186, -0.01092206, ...,  0.02876971,
#         0.00202386,  0.0045556 ])), Entity(name=voters, label=Group, properties=embeddings=array([ 0.01862575,  0.00831917, -0.01696206, ...,  0.01347084,
#         0.01462197,  0.00480169])), Entity(name=ohio, label=Location, properties=embeddings=array([-0.00687917,  0.03646871, -0.00516621, ...,  0.01281954,
#         0.00190859,  0.01631901]))]. Solving them ...
# {'relationships': [{'startNode': {'name': 'voters', 'label': 'Group'}, 'endNode': {'name': 'local election', 'label': 'Event'}, 'name': 'participated in'}, {'startNode': {'name': 'local election', 'label': 'Event'}, 'endNode': {'name': 'ohio', 'label': 'Location'}, 'name': 'held in'}, {'startNode': {'name': 'local election', 'label': 'Event'}, 'endNode': {'name': 'October 15, 2025', 'label': 'Date'}, 'name': 'occurred on'}]}
# [INFO] Verification of invented entities
# [INFO][INVENTED ENTITIES] Aie; the entities label='Date' name='october 15, 2025' properties=EntityProperties(embeddings=None) is invented. Solving it ...
# [INFO] Wohoo! Entity was matched --- [october 15, 2025:Date] --merged--> [november 2, 2025:Date]
# [INFO] ------- Extracting Entities from the Document 9
# {'entities': [{'name': 'Ohio Election', 'label': 'Event'}]}
# [INFO] Wohoo! Entity was matched --- [ohio election:Event] --merged--> [local election:Event]
# [INFO] ------- Extracting Relations from the Document 9
# {'relationships': [{'startNode': {'name': 'local election', 'label': 'Event'}, 'endNode': {'name': 'local election', 'label': 'Event'}, 'name': 'was contested in'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 10
# {'entities': [{'name': 'Incumbent Mayor', 'label': 'Person'}, {'name': 'Ohio', 'label': 'Location'}, {'name': 'Urban Renewal', 'label': 'Process'}]}
# [INFO] ------- Extracting Relations from the Document 10
# {'relationships': [{'startNode': {'name': 'incumbent mayor', 'label': 'Person'}, 'endNode': {'name': 'urban renewal', 'label': 'Process'}, 'name': 'credited with'}, {'startNode': {'name': 'urban renewal', 'label': 'Process'}, 'endNode': {'name': 'ohio', 'label': 'Location'}, 'name': 'in'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 11
# {'entities': [{'name': 'Incumbent Mayor', 'label': 'Person'}, {'name': 'Community Activist', 'label': 'Person'}]}
# [INFO] ------- Extracting Relations from the Document 11
# {'relationships': [{'startNode': {'name': 'incumbent mayor', 'label': 'Person'}, 'endNode': {'name': 'community activist', 'label': 'Person'}, 'name': 'faced a strong challenge from'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 12
# {'entities': [{'name': 'Exit Polls', 'label': 'Process'}, {'name': 'Incumbent Mayor', 'label': 'Person'}, {'name': 'Narrow Victory', 'label': 'Outcome'}]}
# [INFO] ------- Extracting Relations from the Document 12
# {'relationships': [{'startNode': {'name': 'exit polls', 'label': 'Process'}, 'endNode': {'name': 'narrow victory', 'label': 'Outcome'}, 'name': 'predicted'}, {'startNode': {'name': 'narrow victory', 'label': 'Outcome'}, 'endNode': {'name': 'incumbent mayor', 'label': 'Person'}, 'name': 'for'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 13
# {'entities': [{'name': 'Ohio', 'label': 'Location'}, {'name': 'Precincts', 'label': 'Entity'}, {'name': 'Irregularities', 'label': 'Event'}, {'name': 'Election', 'label': 'Event'}]}
# [INFO] Wohoo! Entity was matched --- [election:Event] --merged--> [local election:Event]
# [INFO] ------- Extracting Relations from the Document 13
# {'relationships': [{'startNode': {'name': 'precincts', 'label': 'Entity'}, 'endNode': {'name': 'irregularities', 'label': 'Event'}, 'name': 'reported'}, {'startNode': {'name': 'irregularities', 'label': 'Event'}, 'endNode': {'name': 'local election', 'label': 'Event'}, 'name': 'occurred during'}, {'startNode': {'name': 'precincts', 'label': 'Entity'}, 'endNode': {'name': 'ohio', 'label': 'Location'}, 'name': 'located in'}]}
# [INFO] Verification of invented entities
# [INFO] Wohoo! Relation was matched --- [occurred_during] --merged --> [occurred_on]
# [INFO] ------- Extracting Entities from the Document 14
# {'entities': [{'name': 'Irregularities', 'label': 'Event'}, {'name': 'Debates', 'label': 'Process'}]}
# [INFO] Wohoo! Entity was matched --- [debates:Process] --merged--> [debates:Activity]
# [INFO] ------- Extracting Relations from the Document 14
# {'relationships': [{'startNode': {'name': 'irregularities', 'label': 'Event'}, 'endNode': {'name': 'debates', 'label': 'Activity'}, 'name': 'sparked'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 15
# {'entities': [{'name': 'Local media', 'label': 'Organization'}, {'name': 'election situation', 'label': 'Event'}]}
# [INFO] Wohoo! Entity was matched --- [election situation:Event] --merged--> [local election:Event]
# [INFO] ------- Extracting Relations from the Document 15
# {'relationships': [{'startNode': {'name': 'local media', 'label': 'Organization'}, 'endNode': {'name': 'local election', 'label': 'Event'}, 'name': 'follows up on'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 16
# {'entities': [{'name': 'Major Corporation 1', 'label': 'Corporation'}, {'name': 'Major Corporation 2', 'label': 'Corporation'}, {'name': 'Merger Announcement', 'label': 'Event'}, {'name': 'December 5, 2025', 'label': 'Date'}]}
# [INFO] Wohoo! Entity was matched --- [december 5, 2025:Date] --merged--> [november 2, 2025:Date]
# [INFO] ------- Extracting Relations from the Document 16
# {'relationships': [{'startNode': {'name': 'merger announcement', 'label': 'Event'}, 'endNode': {'name': 'major corporation 1', 'label': 'Corporation'}, 'name': 'involves'}, {'startNode': {'name': 'merger announcement', 'label': 'Event'}, 'endNode': {'name': 'major corporation 2', 'label': 'Corporation'}, 'name': 'involves'}, {'startNode': {'name': 'merger announcement', 'label': 'Event'}, 'endNode': {'name': 'november 2, 2025', 'label': 'Date'}, 'name': 'announced on'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 17
# {'entities': [{'name': 'Merger Deal', 'label': 'Process'}, {'name': '50 Billion Dollars', 'label': 'Value'}]}
# [INFO] ------- Extracting Relations from the Document 17
# {'relationships': [{'startNode': {'name': 'merger deal', 'label': 'Process'}, 'endNode': {'name': '50 billion dollars', 'label': 'Value'}, 'name': 'is valued at'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 18
# {'entities': [{'name': 'Merger', 'label': 'Process'}, {'name': 'Global Leader', 'label': 'Entity'}, {'name': 'Digital Services', 'label': 'Industry'}]}
# [INFO] Wohoo! Entity was matched --- [merger:Process] --merged--> [merger deal:Process]
# [INFO] ------- Extracting Relations from the Document 18
# {'relationships': [{'startNode': {'name': 'merger deal', 'label': 'Process'}, 'endNode': {'name': 'global leader', 'label': 'Entity'}, 'name': 'creates'}, {'startNode': {'name': 'global leader', 'label': 'Entity'}, 'endNode': {'name': 'digital services', 'label': 'Industry'}, 'name': 'in'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 19
# {'entities': [{'name': 'Merger', 'label': 'Process'}, {'name': 'Operations', 'label': 'Process'}, {'name': 'Continents', 'label': 'Geographical Entity'}]}
# [INFO] Wohoo! Entity was matched --- [merger:Process] --merged--> [merger deal:Process]
# [INFO] ------- Extracting Relations from the Document 19
# {'relationships': [{'startNode': {'name': 'merger deal', 'label': 'Process'}, 'endNode': {'name': 'operations', 'label': 'Process'}, 'name': 'aims to streamline'}, {'startNode': {'name': 'operations', 'label': 'Process'}, 'endNode': {'name': 'continents', 'label': 'Geographical_Entity'}, 'name': 'across'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 20
# {'entities': [{'name': 'Company Executives', 'label': 'Person'}, {'name': 'Union', 'label': 'Organization'}, {'name': 'Innovation', 'label': 'Process'}]}
# [INFO] ------- Extracting Relations from the Document 20
# {'relationships': [{'startNode': {'name': 'company executives', 'label': 'Person'}, 'endNode': {'name': 'union', 'label': 'Organization'}, 'name': 'emphasized'}, {'startNode': {'name': 'union', 'label': 'Organization'}, 'endNode': {'name': 'innovation', 'label': 'Process'}, 'name': 'foster'}]}
# [INFO] Verification of invented entities
# [INFO] Wohoo! Relation was matched --- [emphasized] --merged --> [emphasize]
# [INFO] ------- Extracting Entities from the Document 21
# {'entities': [{'name': 'Company executives', 'label': 'Person'}, {'name': 'merger', 'label': 'Process'}, {'name': 'competitive advantages', 'label': 'Concept'}]}
# [INFO] Wohoo! Entity was matched --- [merger:Process] --merged--> [merger deal:Process]
# [INFO] ------- Extracting Relations from the Document 21
# {'relationships': [{'startNode': {'name': 'company executives', 'label': 'Person'}, 'endNode': {'name': 'merger deal', 'label': 'Process'}, 'name': 'stated'}, {'startNode': {'name': 'merger deal', 'label': 'Process'}, 'endNode': {'name': 'competitive advantages', 'label': 'Concept'}, 'name': 'drive'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Copenhagen', 'label': 'Location'}, {'name': 'International Climate Summit', 'label': 'Event'}, {'name': 'World Leaders', 'label': 'Group'}, {'name': 'November 2, 2025', 'label': 'Date'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'world leaders', 'label': 'Group'}, 'endNode': {'name': 'international climate summit', 'label': 'Event'}, 'name': 'attended'}, {'startNode': {'name': 'international climate summit', 'label': 'Event'}, 'endNode': {'name': 'copenhagen', 'label': 'Location'}, 'name': 'held in'}, {'startNode': {'name': 'international climate summit', 'label': 'Event'}, 'endNode': {'name': 'november 2, 2025', 'label': 'Date'}, 'name': 'occurred on'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 2
# {'entities': [{'name': 'Summit', 'label': 'Event'}, {'name': 'Carbon Emissions', 'label': 'Environmental Issue'}, {'name': 'Reducing', 'label': 'Objective'}]}
# [INFO] Wohoo! Entity was matched --- [summit:Event] --merged--> [international climate summit:Event]
# [INFO] ------- Extracting Relations from the Document 2
# {'relationships': [{'startNode': {'name': 'international climate summit', 'label': 'Event'}, 'endNode': {'name': 'carbon emissions', 'label': 'Environmental_Issue'}, 'name': 'aimed at addressing'}, {'startNode': {'name': 'international climate summit', 'label': 'Event'}, 'endNode': {'name': 'reducing', 'label': 'Objective'}, 'name': 'has objective'}, {'startNode': {'name': 'reducing', 'label': 'Objective'}, 'endNode': {'name': 'carbon emissions', 'label': 'Environmental_Issue'}, 'name': 'applies to'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 3
# {'entities': [{'name': 'Summit', 'label': 'Event'}, {'name': 'Renewable Energy Targets', 'label': 'Topic'}, {'name': 'Debates', 'label': 'Activity'}]}
# [INFO] Wohoo! Entity was matched --- [summit:Event] --merged--> [international climate summit:Event]
# [INFO] ------- Extracting Relations from the Document 3
# {'relationships': [{'startNode': {'name': 'international climate summit', 'label': 'Event'}, 'endNode': {'name': 'debates', 'label': 'Activity'}, 'name': 'features'}, {'startNode': {'name': 'debates', 'label': 'Activity'}, 'endNode': {'name': 'renewable energy targets', 'label': 'Topic'}, 'name': 'on'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 4
# {'entities': [{'name': 'Summit', 'label': 'Event'}, {'name': 'Debates', 'label': 'Process'}, {'name': 'Financing Mechanisms', 'label': 'Technique'}, {'name': 'Green Projects', 'label': 'Project'}]}
# [INFO] Wohoo! Entity was matched --- [summit:Event] --merged--> [international climate summit:Event]
# [INFO] Wohoo! Entity was matched --- [debates:Process] --merged--> [debates:Activity]
# [INFO] ------- Extracting Relations from the Document 4
# {'relationships': [{'startNode': {'name': 'debates', 'label': 'Activity'}, 'endNode': {'name': 'financing mechanisms', 'label': 'Technique'}, 'name': 'feature'}, {'startNode': {'name': 'financing mechanisms', 'label': 'Technique'}, 'endNode': {'name': 'green projects', 'label': 'Project'}, 'name': 'support'}, {'startNode': {'name': 'debates', 'label': 'Activity'}, 'endNode': {'name': 'green projects', 'label': 'Project'}, 'name': 'discuss'}, {'startNode': {'name': 'international climate summit', 'label': 'Event'}, 'endNode': {'name': 'debates', 'label': 'Activity'}, 'name': 'include'}]}
# [INFO] Verification of invented entities
# [INFO] Wohoo! Relation was matched --- [feature] --merged --> [features]
# [INFO] ------- Extracting Entities from the Document 5
# {'entities': [{'name': 'Delegates', 'label': 'Group'}, {'name': 'Countries', 'label': 'Geopolitical Entity'}, {'name': 'Coordinated Action', 'label': 'Process'}]}
# [INFO] ------- Extracting Relations from the Document 5
# {'relationships': [{'startNode': {'name': 'delegates', 'label': 'Group'}, 'endNode': {'name': 'countries', 'label': 'Geopolitical_Entity'}, 'name': 'represent'}, {'startNode': {'name': 'delegates', 'label': 'Group'}, 'endNode': {'name': 'coordinated action', 'label': 'Process'}, 'name': 'emphasize'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 6
# {'entities': [{'name': 'Environmental groups', 'label': 'Organization'}, {'name': 'commitments', 'label': 'Concept'}, {'name': 'summit', 'label': 'Event'}]}
# [INFO] Wohoo! Entity was matched --- [summit:Event] --merged--> [international climate summit:Event]
# [INFO] ------- Extracting Relations from the Document 6
# {'relationships': [{'startNode': {'name': 'environmental groups', 'label': 'Organization'}, 'endNode': {'name': 'commitments', 'label': 'Concept'}, 'name': 'lauded'}, {'startNode': {'name': 'commitments', 'label': 'Concept'}, 'endNode': {'name': 'international climate summit', 'label': 'Event'}, 'name': 'made at'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 7
# {'entities': [{'name': 'Negotiators', 'label': 'Person'}, {'name': 'Consensus', 'label': 'Process'}, {'name': 'Interim Emission Reduction Goals', 'label': 'Objective'}]}
# [INFO] ------- Extracting Relations from the Document 7
# {'relationships': [{'startNode': {'name': 'negotiators', 'label': 'Person'}, 'endNode': {'name': 'consensus', 'label': 'Process'}, 'name': 'reached'}, {'startNode': {'name': 'consensus', 'label': 'Process'}, 'endNode': {'name': 'interim emission reduction goals', 'label': 'Objective'}, 'name': 'on'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 8
# {'entities': [{'name': 'Ohio', 'label': 'Location'}, {'name': 'local election', 'label': 'Event'}, {'name': 'October 15, 2025', 'label': 'Date'}, {'name': 'voters', 'label': 'Group'}]}
# [INFO] Wohoo! Entity was matched --- [october 15, 2025:Date] --merged--> [november 2, 2025:Date]
# [INFO] ------- Extracting Relations from the Document 8
# {'relationships': [{'startNode': {'name': 'voters', 'label': 'Group'}, 'endNode': {'name': 'local election', 'label': 'Event'}, 'name': 'participated in'}, {'startNode': {'name': 'local election', 'label': 'Event'}, 'endNode': {'name': 'ohio', 'label': 'Location'}, 'name': 'held in'}]}
# [INFO] Verification of invented entities
# [INFO][ISOLATED ENTITIES][TRY-1] Aie; there are some isolated entities without relations [Entity(name=november 2, 2025, label=Date, properties=embeddings=array([-0.01087675, -0.00051011, -0.00677787, ..., -0.00349423,
#        -0.00276165, -0.00237552]))]. Solving them ...
# {'relationships': []}
# [INFO] Verification of invented entities
# [INFO][ISOLATED ENTITIES][TRY-2] Aie; there are some isolated entities without relations [Entity(name=november 2, 2025, label=Date, properties=embeddings=array([-0.01087675, -0.00051011, -0.00677787, ..., -0.00349423,
#        -0.00276165, -0.00237552])), Entity(name=local election, label=Event, properties=embeddings=array([-0.00306032, -0.01254715, -0.01092098, ...,  0.02876568,
#         0.00203368,  0.00453576])), Entity(name=voters, label=Group, properties=embeddings=array([ 0.01862959,  0.00831324, -0.0169723 , ...,  0.01345342,
#         0.01462047,  0.00479587])), Entity(name=ohio, label=Location, properties=embeddings=array([-0.00688318,  0.03646685, -0.00514475, ...,  0.01282669,
#         0.00191238,  0.01631493]))]. Solving them ...
# {'relationships': [{'startNode': {'name': 'voters', 'label': 'Group'}, 'endNode': {'name': 'local election', 'label': 'Event'}, 'name': 'participated in'}, {'startNode': {'name': 'local election', 'label': 'Event'}, 'endNode': {'name': 'ohio', 'label': 'Location'}, 'name': 'held in'}]}
# [INFO] Verification of invented entities
# [INFO][ISOLATED ENTITIES][TRY-3] Aie; there are some isolated entities without relations [Entity(name=november 2, 2025, label=Date, properties=embeddings=array([-0.01087675, -0.00051011, -0.00677787, ..., -0.00349423,
#        -0.00276165, -0.00237552]))]. Solving them ...
# {'relationships': []}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 9
# {'entities': [{'name': 'Ohio Election', 'label': 'Event'}]}
# [INFO] Wohoo! Entity was matched --- [ohio election:Event] --merged--> [local election:Event]
# [INFO] ------- Extracting Relations from the Document 9
# {'relationships': [{'startNode': {'name': 'local election', 'label': 'Event'}, 'endNode': {'name': 'local election', 'label': 'Event'}, 'name': 'was contested in'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 10
# {'entities': [{'name': 'Incumbent Mayor', 'label': 'Person'}, {'name': 'Ohio', 'label': 'Location'}, {'name': 'Urban Renewal', 'label': 'Process'}]}
# [INFO] ------- Extracting Relations from the Document 10
# {'relationships': [{'startNode': {'name': 'incumbent mayor', 'label': 'Person'}, 'endNode': {'name': 'urban renewal', 'label': 'Process'}, 'name': 'credited with'}, {'startNode': {'name': 'urban renewal', 'label': 'Process'}, 'endNode': {'name': 'ohio', 'label': 'Location'}, 'name': 'occurred in'}]}
# [INFO] Verification of invented entities
# [INFO] Wohoo! Relation was matched --- [occurred_in] --merged --> [occurred_on]
# [INFO] ------- Extracting Entities from the Document 11
# {'entities': [{'name': 'Incumbent Mayor', 'label': 'Person'}, {'name': 'Community Activist', 'label': 'Person'}]}
# [INFO] ------- Extracting Relations from the Document 11
# {'relationships': [{'startNode': {'name': 'incumbent mayor', 'label': 'Person'}, 'endNode': {'name': 'community activist', 'label': 'Person'}, 'name': 'faced a challenge from'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 12
# {'entities': [{'name': 'Exit Polls', 'label': 'Process'}, {'name': 'Incumbent Mayor', 'label': 'Person'}, {'name': 'Narrow Victory', 'label': 'Outcome'}]}
# [INFO] ------- Extracting Relations from the Document 12
# {'relationships': [{'startNode': {'name': 'exit polls', 'label': 'Process'}, 'endNode': {'name': 'narrow victory', 'label': 'Outcome'}, 'name': 'predicted'}, {'startNode': {'name': 'narrow victory', 'label': 'Outcome'}, 'endNode': {'name': 'incumbent mayor', 'label': 'Person'}, 'name': 'for'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 13
# {'entities': [{'name': 'Ohio', 'label': 'Location'}, {'name': 'Precincts', 'label': 'Administrative Division'}, {'name': 'Irregularities', 'label': 'Event'}, {'name': 'Election', 'label': 'Event'}]}
# [INFO] Wohoo! Entity was matched --- [election:Event] --merged--> [local election:Event]
# [INFO] ------- Extracting Relations from the Document 13
# {'relationships': [{'startNode': {'name': 'precincts', 'label': 'Administrative_Division'}, 'endNode': {'name': 'irregularities', 'label': 'Event'}, 'name': 'reported in'}, {'startNode': {'name': 'irregularities', 'label': 'Event'}, 'endNode': {'name': 'local election', 'label': 'Event'}, 'name': 'occurred during'}, {'startNode': {'name': 'precincts', 'label': 'Administrative_Division'}, 'endNode': {'name': 'ohio', 'label': 'Location'}, 'name': 'located in'}]}
# [INFO] Verification of invented entities
# [INFO] Wohoo! Relation was matched --- [occurred_during] --merged --> [occurred_on]
# [INFO] ------- Extracting Entities from the Document 14
# {'entities': [{'name': 'Irregularities', 'label': 'Event'}, {'name': 'Debates', 'label': 'Event'}]}
# [INFO] Wohoo! Entity was matched --- [debates:Event] --merged--> [debates:Activity]
# [INFO] ------- Extracting Relations from the Document 14
# {'relationships': [{'startNode': {'name': 'irregularities', 'label': 'Event'}, 'endNode': {'name': 'debates', 'label': 'Activity'}, 'name': 'sparked'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 15
# {'entities': [{'name': 'Local media', 'label': 'Organization'}, {'name': 'election situation', 'label': 'Event'}]}
# [INFO] Wohoo! Entity was matched --- [election situation:Event] --merged--> [local election:Event]
# [INFO] ------- Extracting Relations from the Document 15
# {'relationships': [{'startNode': {'name': 'local media', 'label': 'Organization'}, 'endNode': {'name': 'local election', 'label': 'Event'}, 'name': 'follows up on'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 16
# {'entities': [{'name': 'Major Corporation 1', 'label': 'Corporation'}, {'name': 'Major Corporation 2', 'label': 'Corporation'}, {'name': 'Merger Announcement', 'label': 'Event'}, {'name': 'December 5, 2025', 'label': 'Date'}]}
# [INFO] Wohoo! Entity was matched --- [december 5, 2025:Date] --merged--> [november 2, 2025:Date]
# [INFO] ------- Extracting Relations from the Document 16
# {'relationships': [{'startNode': {'name': 'major corporation 1', 'label': 'Corporation'}, 'endNode': {'name': 'merger announcement', 'label': 'Event'}, 'name': 'involved in'}, {'startNode': {'name': 'major corporation 2', 'label': 'Corporation'}, 'endNode': {'name': 'merger announcement', 'label': 'Event'}, 'name': 'involved in'}]}
# [INFO] Verification of invented entities
# [INFO][ISOLATED ENTITIES][TRY-1] Aie; there are some isolated entities without relations [Entity(name=november 2, 2025, label=Date, properties=embeddings=array([-0.01087675, -0.00051011, -0.00677787, ..., -0.00349423,
#        -0.00276165, -0.00237552]))]. Solving them ...
# {'relationships': []}
# [INFO] Verification of invented entities
# [INFO][ISOLATED ENTITIES][TRY-2] Aie; there are some isolated entities without relations [Entity(name=merger announcement, label=Event, properties=embeddings=array([-0.01690577,  0.00861437, -0.01530141, ...,  0.00704119,
#         0.01220006, -0.01276702])), Entity(name=major corporation 1, label=Corporation, properties=embeddings=array([ 0.00901588, -0.00187075, -0.01222094, ...,  0.00286869,
#        -0.01551806, -0.00913678])), Entity(name=november 2, 2025, label=Date, properties=embeddings=array([-0.01087675, -0.00051011, -0.00677787, ..., -0.00349423,
#        -0.00276165, -0.00237552])), Entity(name=major corporation 2, label=Corporation, properties=embeddings=array([ 0.01311392,  0.00222466, -0.01503093, ...,  0.00660783,
#        -0.0218163 , -0.00294312]))]. Solving them ...
# {'relationships': [{'startNode': {'name': 'merger announcement', 'label': 'Event'}, 'endNode': {'name': 'major corporation 1', 'label': 'Corporation'}, 'name': 'involves'}, {'startNode': {'name': 'merger announcement', 'label': 'Event'}, 'endNode': {'name': 'major corporation 2', 'label': 'Corporation'}, 'name': 'involves'}, {'startNode': {'name': 'merger announcement', 'label': 'Event'}, 'endNode': {'name': 'november 2, 2025', 'label': 'Date'}, 'name': 'announced on'}]}
# [INFO] Verification of invented entities
# [INFO] Wohoo! Relation was matched --- [involved_in] --merged --> [participated_in]
# [INFO] Wohoo! Relation was matched --- [involved_in] --merged --> [participated_in]
# [INFO] ------- Extracting Entities from the Document 17
# {'entities': [{'name': 'Merger Deal', 'label': 'Process'}, {'name': '50 billion dollars', 'label': 'Value'}]}
# [INFO] ------- Extracting Relations from the Document 17
# {'relationships': [{'startNode': {'name': 'merger deal', 'label': 'Process'}, 'endNode': {'name': '50 billion dollars', 'label': 'Value'}, 'name': 'is valued at'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 18
# {'entities': [{'name': 'Merger', 'label': 'Process'}, {'name': 'Global Leader', 'label': 'Entity'}, {'name': 'Digital Services', 'label': 'Industry'}]}
# [INFO] Wohoo! Entity was matched --- [merger:Process] --merged--> [merger deal:Process]
# [INFO] ------- Extracting Relations from the Document 18
# {'relationships': [{'startNode': {'name': 'merger deal', 'label': 'Process'}, 'endNode': {'name': 'global leader', 'label': 'Entity'}, 'name': 'creates'}, {'startNode': {'name': 'global leader', 'label': 'Entity'}, 'endNode': {'name': 'digital services', 'label': 'Industry'}, 'name': 'in'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 19
# {'entities': [{'name': 'Merger', 'label': 'Process'}, {'name': 'Operations', 'label': 'Process'}, {'name': 'Continents', 'label': 'Geographical Entity'}]}
# [INFO] Wohoo! Entity was matched --- [merger:Process] --merged--> [merger deal:Process]
# [INFO] ------- Extracting Relations from the Document 19
# {'relationships': [{'startNode': {'name': 'merger deal', 'label': 'Process'}, 'endNode': {'name': 'operations', 'label': 'Process'}, 'name': 'aims to streamline'}, {'startNode': {'name': 'operations', 'label': 'Process'}, 'endNode': {'name': 'continents', 'label': 'Geographical_Entity'}, 'name': 'across'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 20
# {'entities': [{'name': 'Company Executives', 'label': 'Person'}, {'name': 'Union', 'label': 'Organization'}, {'name': 'Innovation', 'label': 'Process'}]}
# [INFO] ------- Extracting Relations from the Document 20
# {'relationships': [{'startNode': {'name': 'company executives', 'label': 'Person'}, 'endNode': {'name': 'union', 'label': 'Organization'}, 'name': 'emphasized'}, {'startNode': {'name': 'union', 'label': 'Organization'}, 'endNode': {'name': 'innovation', 'label': 'Process'}, 'name': 'foster'}]}
# [INFO] Verification of invented entities
# [INFO] Wohoo! Relation was matched --- [emphasized] --merged --> [emphasize]
# [INFO] ------- Extracting Entities from the Document 21
# {'entities': [{'name': 'Company Executives', 'label': 'Person'}, {'name': 'Merger', 'label': 'Process'}, {'name': 'Competitive Advantages', 'label': 'Concept'}]}
# [INFO] Wohoo! Entity was matched --- [merger:Process] --merged--> [merger deal:Process]
# [INFO] ------- Extracting Relations from the Document 21
# {'relationships': [{'startNode': {'name': 'company executives', 'label': 'Person'}, 'endNode': {'name': 'merger deal', 'label': 'Process'}, 'name': 'stated'}, {'startNode': {'name': 'merger deal', 'label': 'Process'}, 'endNode': {'name': 'competitive advantages', 'label': 'Concept'}, 'name': 'drive'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 22
# {'entities': [{'name': 'Regulatory authorities', 'label': 'Organization'}, {'name': 'transaction', 'label': 'Process'}, {'name': 'next month', 'label': 'Time'}]}
# [INFO] Wohoo! Entity was matched --- [transaction:Process] --merged--> [operations:Process]
# [INFO] ------- Extracting Relations from the Document 22
# {'relationships': [{'startNode': {'name': 'regulatory authorities', 'label': 'Organization'}, 'endNode': {'name': 'next month', 'label': 'Time'}, 'name': 'review in'}]}
# [INFO] Verification of invented entities
# [INFO][ISOLATED ENTITIES][TRY-1] Aie; there are some isolated entities without relations [Entity(name=operations, label=Process, properties=embeddings=array([ 0.01853189, -0.00471278, -0.01094075, ..., -0.00493027,
#        -0.0136942 ,  0.00776429]))]. Solving them ...
# {'relationships': []}
# [INFO] Verification of invented entities
# [INFO][ISOLATED ENTITIES][TRY-2] Aie; there are some isolated entities without relations [Entity(name=regulatory authorities, label=Organization, properties=embeddings=array([-0.00153283,  0.01972019, -0.02390591, ...,  0.00317369,
#         0.02331148, -0.00998546])), Entity(name=operations, label=Process, properties=embeddings=array([ 0.01853189, -0.00471278, -0.01094075, ..., -0.00493027,
#        -0.0136942 ,  0.00776429])), Entity(name=next month, label=Time, properties=embeddings=array([-0.02260186, -0.01725102,  0.00434634, ...,  0.01591684,
#         0.00207187, -0.00272095]))]. Solving them ...
# {'relationships': [{'startNode': {'name': 'regulatory authorities', 'label': 'Organization'}, 'endNode': {'name': 'next month', 'label': 'Time'}, 'name': 'will review in'}]}
# [INFO] Verification of invented entities
# [INFO] Wohoo! Relation was matched --- [will_review_in] --merged --> [review_in]
# [INFO][ISOLATED ENTITIES][TRY-3] Aie; there are some isolated entities without relations [Entity(name=operations, label=Process, properties=embeddings=array([ 0.01853189, -0.00471278, -0.01094075, ..., -0.00493027,
#        -0.0136942 ,  0.00776429]))]. Solving them ...
# {'relationships': []}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 23
# {'entities': [{'name': 'Market Disruption', 'label': 'Process'}, {'name': 'Merger', 'label': 'Process'}, {'name': 'Industry Experts', 'label': 'Person'}]}
# [INFO] Wohoo! Entity was matched --- [industry experts:Person] --merged--> [company executives:Person]
# [INFO] Wohoo! Entity was matched --- [merger:Process] --merged--> [merger deal:Process]
# [INFO] ------- Extracting Relations from the Document 23
# {'relationships': [{'startNode': {'name': 'merger deal', 'label': 'Process'}, 'endNode': {'name': 'market disruption', 'label': 'Process'}, 'name': 'causes'}]}
# [INFO] Verification of invented entities
# [INFO][ISOLATED ENTITIES][TRY-1] Aie; there are some isolated entities without relations [Entity(name=company executives, label=Person, properties=embeddings=array([ 0.00575834, -0.003634  , -0.01703701, ...,  0.00540274,
#         0.00480735, -0.01245348]))]. Solving them ...
# {'relationships': []}
# [INFO] Verification of invented entities
# [INFO][ISOLATED ENTITIES][TRY-2] Aie; there are some isolated entities without relations [Entity(name=market disruption, label=Process, properties=embeddings=array([ 0.00947825, -0.02743276, -0.00085026, ..., -0.00202752,
#        -0.01278769, -0.00367772])), Entity(name=company executives, label=Person, properties=embeddings=array([ 0.00575834, -0.003634  , -0.01703701, ...,  0.00540274,
#         0.00480735, -0.01245348])), Entity(name=merger deal, label=Process, properties=embeddings=array([ 0.00106881,  0.00305035, -0.00906141, ...,  0.00617294,
#         0.00078072, -0.00842532]))]. Solving them ...
# {'relationships': [{'startNode': {'name': 'merger deal', 'label': 'Process'}, 'endNode': {'name': 'market disruption', 'label': 'Process'}, 'name': 'causes'}]}
# [INFO] Verification of invented entities
# [INFO][ISOLATED ENTITIES][TRY-3] Aie; there are some isolated entities without relations [Entity(name=company executives, label=Person, properties=embeddings=array([ 0.00575834, -0.003634  , -0.01703701, ...,  0.00540274,
#         0.00480735, -0.01245348]))]. Solving them ...
# {'relationships': []}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 24
# {'entities': [{'name': 'Relief Agencies', 'label': 'Organization'}, {'name': 'Emergency Resources', 'label': 'Resource'}, {'name': 'Severe Flooding', 'label': 'Event'}, {'name': 'Delta Region', 'label': 'Location'}, {'name': 'January 22, 2025', 'label': 'Date'}]}
# [INFO] Wohoo! Entity was matched --- [january 22, 2025:Date] --merged--> [november 2, 2025:Date]
# [INFO] ------- Extracting Relations from the Document 24
# {'relationships': [{'startNode': {'name': 'relief agencies', 'label': 'Organization'}, 'endNode': {'name': 'emergency resources', 'label': 'Resource'}, 'name': 'mobilized'}, {'startNode': {'name': 'severe flooding', 'label': 'Event'}, 'endNode': {'name': 'delta region', 'label': 'Location'}, 'name': 'occurred in'}, {'startNode': {'name': 'emergency resources', 'label': 'Resource'}, 'endNode': {'name': 'severe flooding', 'label': 'Event'}, 'name': 'in response to'}]}
# [INFO] Verification of invented entities
# [INFO][ISOLATED ENTITIES][TRY-1] Aie; there are some isolated entities without relations [Entity(name=november 2, 2025, label=Date, properties=embeddings=array([-0.01087675, -0.00051011, -0.00677787, ..., -0.00349423,
#        -0.00276165, -0.00237552]))]. Solving them ...
# {'relationships': []}
# [INFO] Verification of invented entities
# [INFO][ISOLATED ENTITIES][TRY-2] Aie; there are some isolated entities without relations [Entity(name=severe flooding, label=Event, properties=embeddings=array([-0.01295123,  0.01862879,  0.00321188, ...,  0.00496466,
#        -0.00651227, -0.00553017])), Entity(name=november 2, 2025, label=Date, properties=embeddings=array([-0.01087675, -0.00051011, -0.00677787, ..., -0.00349423,
#        -0.00276165, -0.00237552])), Entity(name=delta region, label=Location, properties=embeddings=array([ 0.00816395,  0.02377871,  0.00130292, ...,  0.00999661,
#        -0.00120431,  0.01492088])), Entity(name=emergency resources, label=Resource, properties=embeddings=array([-0.02006983,  0.01150094, -0.00704908, ..., -0.00318755,
#        -0.00660067,  0.00473837])), Entity(name=relief agencies, label=Organization, properties=embeddings=array([-0.01078438,  0.01416761, -0.02370669, ..., -0.01624001,
#         0.00369802, -0.01487038]))]. Solving them ...
# {'relationships': [{'startNode': {'name': 'relief agencies', 'label': 'Organization'}, 'endNode': {'name': 'emergency resources', 'label': 'Resource'}, 'name': 'mobilized'}, {'startNode': {'name': 'severe flooding', 'label': 'Event'}, 'endNode': {'name': 'delta region', 'label': 'Location'}, 'name': 'occurred in'}, {'startNode': {'name': 'severe flooding', 'label': 'Event'}, 'endNode': {'name': 'emergency resources', 'label': 'Resource'}, 'name': 'necessitated'}, {'startNode': {'name': 'severe flooding', 'label': 'Event'}, 'endNode': {'name': 'relief agencies', 'label': 'Organization'}, 'name': 'prompted'}]}
# [INFO] Verification of invented entities
# [INFO][ISOLATED ENTITIES][TRY-3] Aie; there are some isolated entities without relations [Entity(name=november 2, 2025, label=Date, properties=embeddings=array([-0.01087675, -0.00051011, -0.00677787, ..., -0.00349423,
#        -0.00276165, -0.00237552]))]. Solving them ...
# {'relationships': []}
# [INFO] Verification of invented entities
# [INFO] Wohoo! Relation was matched --- [occurred_in] --merged --> [occurred_on]
# [INFO] Wohoo! Relation was matched --- [occurred_in] --merged --> [occurred_on]
# [INFO] ------- Extracting Entities from the Document 25
# {'entities': [{'name': 'Delta region', 'label': 'Location'}, {'name': 'torrential rains', 'label': 'Weather Event'}, {'name': 'Local communities', 'label': 'Group'}, {'name': 'January 22, 2025', 'label': 'Date'}]}
# [INFO] Wohoo! Entity was matched --- [january 22, 2025:Date] --merged--> [november 2, 2025:Date]
# [INFO] ------- Extracting Relations from the Document 25
# {'relationships': [{'startNode': {'name': 'local communities', 'label': 'Group'}, 'endNode': {'name': 'delta region', 'label': 'Location'}, 'name': 'located in'}, {'startNode': {'name': 'torrential rains', 'label': 'Weather_Event'}, 'endNode': {'name': 'delta region', 'label': 'Location'}, 'name': 'occurred in'}, {'startNode': {'name': 'torrential rains', 'label': 'Weather_Event'}, 'endNode': {'name': 'local communities', 'label': 'Group'}, 'name': 'affected'}]}
# [INFO] Verification of invented entities
# [INFO][ISOLATED ENTITIES][TRY-1] Aie; there are some isolated entities without relations [Entity(name=november 2, 2025, label=Date, properties=embeddings=array([-0.01087675, -0.00051011, -0.00677787, ..., -0.00349423,
#        -0.00276165, -0.00237552]))]. Solving them ...
# {'relationships': []}
# [INFO] Verification of invented entities
# [INFO][ISOLATED ENTITIES][TRY-2] Aie; there are some isolated entities without relations [Entity(name=local communities, label=Group, properties=embeddings=array([ 0.01026247,  0.01018173, -0.01942388, ...,  0.01250211,
#         0.00369812,  0.00768717])), Entity(name=november 2, 2025, label=Date, properties=embeddings=array([-0.01087675, -0.00051011, -0.00677787, ..., -0.00349423,
#        -0.00276165, -0.00237552])), Entity(name=delta region, label=Location, properties=embeddings=array([ 0.00818116,  0.02377521,  0.00132501, ...,  0.0100103 ,
#        -0.00121004,  0.01491308])), Entity(name=torrential rains, label=Weather_Event, properties=embeddings=array([-0.02129815, -0.00100316,  0.00499287, ...,  0.00527968,
#        -0.0025821 ,  0.00461703]))]. Solving them ...
# ...
#      77             context=formatted_context, output_data_structure=RelationshipsExtractor,
#      78             IE_query=IE_query
#      79         )
#      81         if relationships and "relationships" in relationships.keys():
#      82             break
#
# File ~/.pyenv/versions/3.11.1/envs/test-itext2kg/lib/python3.11/site-packages/itext2kg/utils/llm_output_parser.py:93, in LangchainOutputParser.extract_information_as_json_for_context(self, output_data_structure, context, IE_query)
#      91 chain = prompt | self.model | parser
#      92 try:
# ---> 93     return chain.invoke({"query": IE_query})
#      94 except openai.BadRequestError as e:
#      95     print(f"Too much requests, we are sleeping! \n the error is {e}")
#
# File ~/.pyenv/versions/3.11.1/envs/test-itext2kg/lib/python3.11/site-packages/langchain_core/runnables/base.py:3024, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3022             input = context.run(step.invoke, input, config, **kwargs)
#    3023         else:
# -> 3024             input = context.run(step.invoke, input, config)
#    3025 # finish the root run
#    3026 except BaseException as e:
#
# File ~/.pyenv/versions/3.11.1/envs/test-itext2kg/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:284, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     273 def invoke(
#     274     self,
#     275     input: LanguageModelInput,
#    (...)    279     **kwargs: Any,
#     280 ) -> BaseMessage:
#     281     config = ensure_config(config)
#     282     return cast(
#     283         ChatGeneration,
# --> 284         self.generate_prompt(
#     285             [self._convert_input(input)],
#     286             stop=stop,
#     287             callbacks=config.get("callbacks"),
#     288             tags=config.get("tags"),
#     289             metadata=config.get("metadata"),
#     290             run_name=config.get("run_name"),
#     291             run_id=config.pop("run_id", None),
#     292             **kwargs,
#     293         ).generations[0][0],
#     294     ).message
#
# File ~/.pyenv/versions/3.11.1/envs/test-itext2kg/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:860, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     852 def generate_prompt(
#     853     self,
#     854     prompts: list[PromptValue],
#    (...)    857     **kwargs: Any,
#     858 ) -> LLMResult:
#     859     prompt_messages = [p.to_messages() for p in prompts]
# --> 860     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/.pyenv/versions/3.11.1/envs/test-itext2kg/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:690, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     687 for i, m in enumerate(messages):
#     688     try:
#     689         results.append(
# --> 690             self._generate_with_cache(
#     691                 m,
#     692                 stop=stop,
#     693                 run_manager=run_managers[i] if run_managers else None,
#     694                 **kwargs,
#     695             )
#     696         )
#     697     except BaseException as e:
#     698         if run_managers:
#
# File ~/.pyenv/versions/3.11.1/envs/test-itext2kg/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:925, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     923 else:
#     924     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 925         result = self._generate(
#     926             messages, stop=stop, run_manager=run_manager, **kwargs
#     927         )
#     928     else:
#     929         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/.pyenv/versions/3.11.1/envs/test-itext2kg/lib/python3.11/site-packages/langchain_openai/chat_models/base.py:790, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     788     generation_info = {"headers": dict(raw_response.headers)}
#     789 else:
# --> 790     response = self.client.create(**payload)
#     791 return self._create_chat_result(response, generation_info)
#
# File ~/.pyenv/versions/3.11.1/envs/test-itext2kg/lib/python3.11/site-packages/openai/_utils/_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.1/envs/test-itext2kg/lib/python3.11/site-packages/openai/resources/chat/completions/completions.py:879, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     837 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     838 def create(
#     839     self,
#    (...)    876     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     877 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     878     validate_response_format(response_format)
# --> 879     return self._post(
#     880         "/chat/completions",
#     881         body=maybe_transform(
#     882             {
#     883                 "messages": messages,
#     884                 "model": model,
#     885                 "audio": audio,
#     886                 "frequency_penalty": frequency_penalty,
#     887                 "function_call": function_call,
#     888                 "functions": functions,
#     889                 "logit_bias": logit_bias,
#     890                 "logprobs": logprobs,
#     891                 "max_completion_tokens": max_completion_tokens,
#     892                 "max_tokens": max_tokens,
#     893                 "metadata": metadata,
#     894                 "modalities": modalities,
#     895                 "n": n,
#     896                 "parallel_tool_calls": parallel_tool_calls,
#     897                 "prediction": prediction,
#     898                 "presence_penalty": presence_penalty,
#     899                 "reasoning_effort": reasoning_effort,
#     900                 "response_format": response_format,
#     901                 "seed": seed,
#     902                 "service_tier": service_tier,
#     903                 "stop": stop,
#     904                 "store": store,
#     905                 "stream": stream,
#     906                 "stream_options": stream_options,
#     907                 "temperature": temperature,
#     908                 "tool_choice": tool_choice,
#     909                 "tools": tools,
#     910                 "top_logprobs": top_logprobs,
#     911                 "top_p": top_p,
#     912                 "user": user,
#     913             },
#     914             completion_create_params.CompletionCreateParams,
#     915         ),
#     916         options=make_request_options(
#     917             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     918         ),
#     919         cast_to=ChatCompletion,
#     920         stream=stream or False,
#     921         stream_cls=Stream[ChatCompletionChunk],
#     922     )
#
# File ~/.pyenv/versions/3.11.1/envs/test-itext2kg/lib/python3.11/site-packages/openai/_base_client.py:1296, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1282 def post(
#    1283     self,
#    1284     path: str,
#    (...)   1291     stream_cls: type[_StreamT] | None = None,
#    1292 ) -> ResponseT | _StreamT:
#    1293     opts = FinalRequestOptions.construct(
#    1294         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1295     )
# -> 1296     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/.pyenv/versions/3.11.1/envs/test-itext2kg/lib/python3.11/site-packages/openai/_base_client.py:973, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     970 else:
#     971     retries_taken = 0
# --> 973 return self._request(
#     974     cast_to=cast_to,
#     975     options=options,
#     976     stream=stream,
#     977     stream_cls=stream_cls,
#     978     retries_taken=retries_taken,
#     979 )
#
# File ~/.pyenv/versions/3.11.1/envs/test-itext2kg/lib/python3.11/site-packages/openai/_base_client.py:1009, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1006 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#    1008 try:
# -> 1009     response = self._client.send(
#    1010         request,
#    1011         stream=stream or self._should_stream_response_body(request=request),
#    1012         **kwargs,
#    1013     )
#    1014 except httpx.TimeoutException as err:
#    1015     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/.pyenv/versions/3.11.1/envs/test-itext2kg/lib/python3.11/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/.pyenv/versions/3.11.1/envs/test-itext2kg/lib/python3.11/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/.pyenv/versions/3.11.1/envs/test-itext2kg/lib/python3.11/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/.pyenv/versions/3.11.1/envs/test-itext2kg/lib/python3.11/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/.pyenv/versions/3.11.1/envs/test-itext2kg/lib/python3.11/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/.pyenv/versions/3.11.1/envs/test-itext2kg/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/.pyenv/versions/3.11.1/envs/test-itext2kg/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/.pyenv/versions/3.11.1/envs/test-itext2kg/lib/python3.11/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/.pyenv/versions/3.11.1/envs/test-itext2kg/lib/python3.11/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/.pyenv/versions/3.11.1/envs/test-itext2kg/lib/python3.11/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/.pyenv/versions/3.11.1/envs/test-itext2kg/lib/python3.11/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/.pyenv/versions/3.11.1/envs/test-itext2kg/lib/python3.11/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/.pyenv/versions/3.11.1/envs/test-itext2kg/lib/python3.11/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/ssl.py:1263, in SSLSocket.recv(self, buflen, flags)
#    1259     if flags != 0:
#    1260         raise ValueError(
#    1261             "non-zero flags not allowed in calls to recv() on %s" %
#    1262             self.__class__)
# -> 1263     return self.read(buflen)
#    1264 else:
#    1265     return super().recv(buflen, flags)
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/ssl.py:1136, in SSLSocket.read(self, len, buffer)
#    1134         return self._sslobj.read(len, buffer)
#    1135     else:
# -> 1136         return self._sslobj.read(len)
#    1137 except SSLError as x:
#    1138     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
